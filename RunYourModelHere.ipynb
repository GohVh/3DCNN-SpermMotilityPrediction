# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %%
# %cp -av /content/gdrive/MyDrive/share/dataset_11f34b/data1 /content/data1

# %%
# !pip install wandb -qqq

# %%
# %run main.py --fold 1

# %%
# %run main.py --fold 2

# %%
# %run main.py --fold 3

# %%
# %run test.py --fold 1 --isSingleTest --singlePath path_here
